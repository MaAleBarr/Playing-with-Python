# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Train.csv')

# %%
data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# ...

# %%
data[['Name','Age']][(data.Sex == 'male') & (pd.isnull(data.Age)) ].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-9c377c0094ff> in <module>()
# ----> 1 data[['Name','Age']][(data.Sex == 'male') & (pd.isnull(data.Age)) ].head()
#
# /Users/mbarr/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other)
#     570
#     571             # scalars
# --> 572             res = na_op(values, other)
#     573             if np.isscalar(res):
#     574                 raise TypeError('Could not compare %s type with Series'
#
# /Users/mbarr/anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     539                 result = getattr(x, name)(y)
#     540                 if result is NotImplemented:
# --> 541                     raise TypeError("invalid type comparison")
#     542             except (AttributeError):
#     543                 result = op(x, y)
#
# ...

# %%
count=len(data)
print count
# Out:
# 891

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name  Sex  Age  SibSp  Parch  \
# 0                             Braund, Mr. Owen Harris    0   22      1      0
# ...

# %%
# female=True, male=False
#data[data.Sex == 'female']=data.replace(to_replace='female', value=True)
#data[data.Sex == 'male']=data.replace(to_replace='male', value=False)

data.Sex.replace('male', 0, inplace=True)
data.Sex.replace('female', 1, inplace=True)

# %%
data[data.Sex == 0]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
# can use mean of all ages
# can use mean of just females and mean of just mean
# can use normal function, mean and stdev to fill in 

# will use normal function, mean and stdev to fill, seperate for females and males
#data.Sex.replace('female', 1, inplace=True)

#dat.Survived[(dat.Sex =='male') & (dat.Age>=50) & (dat.Pclass==1)].mean()

# find mean and stdev of age for males and females
AgeStats=[data.Age.mean(), data.Age.std()]

# print MaleAgeStats
# print FemaleAgeStats
print AgeStats

SnglMeanDat=data.copy()
SnglMeanDat.Age.fillna(value=30, inplace=True)
# Out:
# [30.726644591611478, 14.678200823816601]
# [27.915708812260537, 14.110146457544129]
# [29.69911764705882, 14.526497332334044]

# %%
SnglMeanDat.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
# 5                                   Moran, Mr. James    0   30      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data.Age[data.Sex == 0].fillna(value=MaleAgeStats[0]).head(10)
# Out:
# 0     22.000000
# 4     35.000000
# 5     30.726645
# 6     54.000000
# 7      2.000000
# 12    20.000000
# 13    39.000000
# 16     2.000000
# 17    30.726645
# 20    35.000000
# Name: Age, dtype: float64

# %%
SnglMeanDatFeMa=data.copy()
SnglMeanDatFeMa.Sex.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Sex, dtype: int64

# %%
#data.Age[data.Sex == 1].fillna(value=FemaleAgeStats[0])
#data.Age[data.Sex == 0].fillna(value=MaleAgeStats[0], inplace= True)

SnglMeanDatFeMa.Age[SnglMeanDatFeMa.Sex == 1]=SnglMeanDatFeMa.Age[SnglMeanDatFeMa.Sex == 1].fillna(value=FemaleAgeStats[0])
SnglMeanDatFeMa.Age[SnglMeanDatFeMa.Sex == 0]=SnglMeanDatFeMa.Age[SnglMeanDatFeMa.Sex == 0].fillna(value=MaleAgeStats[0])

SnglMeanDatFeMa.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex        Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    0  22.000000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                             Heikkinen, Miss. Laina    1  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                           Allen, Mr. William Henry    0  35.000000      0
# 5                                   Moran, Mr. James    0  30.726645      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# ...

# %%
numFemale=data.Age[data.Sex==1].count() #data.Age[(data.Sex ==1) & (pd.notnull(data.Age))].count()
numMale=data.Age[data.Sex==0].count() #data.Age[(data.Sex ==0) & (pd.notnull(data.Age))].count()
print numFemale
print numMale
# Out:
# 261
# 453

# %%
# number of male and femail entries
print data.Sex[data.Sex==1].count()
print data.Sex[data.Sex==0].count()

num_nullF=data.Sex[data.Sex==1].count()-numFemale
num_nullM=data.Sex[data.Sex==0].count()-numMale
# Out:
# 314
# 577

# %%
num_val=count-data.Age[data.Age.notnull()== True].count()
vals=np.random.normal(AgeStats[0], AgeStats[1], num_val)

MaleAgeStats=[data.Age[data.Sex == 0].mean(), data.Age[data.Sex == 0].std()]
FemaleAgeStats=[data.Age[data.Sex == 1].mean(), data.Age[data.Sex == 1].std()]

valsF=np.random.normal(FemaleAgeStats[0], FemaleAgeStats[1], num_nullF)
valsM=np.random.normal(MaleAgeStats[0], MaleAgeStats[1], num_nullM)

#print valsF

# %%
AgeStats
# Out:
# [29.69911764705882, 14.526497332334044]

# %%
datNrmDstFM=data.copy()

# %%
datNrmDstFM.Age[datNrmDstFM.Sex==0].fillna(value=valsM)
# Out:
# 0     22.000000
# 4     35.000000
# 5     45.605669
# 6     54.000000
# 7      2.000000
# 12    20.000000
# 13    39.000000
# 16     2.000000
# 17    25.727220
# 20    35.000000
# 21    34.000000
# 23    28.000000
# 26    18.592704
# 27    19.000000
# 29    20.320537
# ...
# 867    31.000000
# 868    52.765161
# 869     4.000000
# 870    26.000000
# 872    33.000000
# 873    47.000000
# 876    20.000000
# 877    19.000000
# 878    17.808200
# 881    33.000000
# 883    28.000000
# 884    25.000000
# 886    27.000000
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 577, dtype: float64

# %%
datNrmDstFM.Age[datNrmDstFM.Sex==1].fillna(valsF)
# Out:
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 14    14.000000
# 15    55.000000
# 18    31.000000
# 19    39.784041
# 22    15.000000
# 24     8.000000
# 25    38.000000
# 28    39.040378
# ...
# 856    45.000000
# 858    24.000000
# 862    48.000000
# 863    17.137337
# 865    42.000000
# 866    27.000000
# 871    47.000000
# 874    28.000000
# 875    15.000000
# 879    56.000000
# 880    25.000000
# 882    22.000000
# 885    39.000000
# 887    19.000000
# 888    40.653865
# Name: Age, Length: 314, dtype: float64

# %%
datNrmDstFM.Age[datNrmDstFM.Sex==1]=datNrmDstFM.Age[datNrmDstFM.Sex==1].fillna(valsF)
datNrmDstFM.Age[datNrmDstFM.Sex==0]=datNrmDstFM.Age[datNrmDstFM.Sex==0].fillna(valsM)

# %%
datNrmDstFM.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name  Sex        Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    0  32.374612      1
# ...

# %%
dataNormDist=data.copy()
#data.Age.fillna(value=vals)
dataNormDist.Age.fillna(value=vals, inplace=True)

# %%
dataNormDist.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex        Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    0  22.000000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                             Heikkinen, Miss. Laina    1  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                           Allen, Mr. William Henry    0  35.000000      0
# 5                                   Moran, Mr. James    0  24.319156      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# ...

# %%
SnglMeanDatFeMa.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
# 5                                   Moran, Mr. James    0  NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
SnglMeanDat.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0   22      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1      0
# 2                             Heikkinen, Miss. Laina    1   26      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1      0
# 4                           Allen, Mr. William Henry    0   35      0      0
# 5                                   Moran, Mr. James    0   30      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
classFrame=pd.get_dummies(data.Pclass)
print classFrame.head(10)
# Out:
#    1  2  3
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  1  0  0
# 4  0  0  1
# 5  0  0  1
# 6  1  0  0
# 7  0  0  1
# 8  0  0  1
# 9  0  1  0

# %%
data.merge(classFrame, left_index=True, right_index=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
